# %% [markdown]
# **BIG BIG HINT! Look in the instructions to guide you on this task.**

# %%
# Dependencies
import pandas as pd

# %%
# load CSV
csv_path = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas
dataunclean_df = pd.read_csv(csv_path, low_memory=False)
dataunclean_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# ...

# %%
# Inspect all columns
for col in dataunclean_df.columns: 
    print(col)
# Out:
# Age
# AttendedBootcamp
# BootcampFinish
# BootcampFullJobAfter
# BootcampLoanYesNo
# BootcampMonthsAgo
# BootcampName
# BootcampPostSalary
# BootcampRecommend
# ChildrenNumber
# CityPopulation
# CodeEventBootcamp
# CodeEventCoffee
# CodeEventConferences
# CodeEventDjangoGirls
# CodeEventGameJam
# CodeEventGirlDev
# CodeEventHackathons
# CodeEventMeetup
# CodeEventNodeSchool
# CodeEventNone
# CodeEventOther
# CodeEventRailsBridge
# CodeEventRailsGirls
# CodeEventStartUpWknd
# CodeEventWomenCode
# CodeEventWorkshop
# CommuteTime
# CountryCitizen
# CountryLive
# EmploymentField
# EmploymentFieldOther
# EmploymentStatus
# EmploymentStatusOther
# ExpectedEarning
# FinanciallySupporting
# Gender
# HasChildren
# HasDebt
# HasFinancialDependents
# HasHighSpdInternet
# HasHomeMortgage
# HasServedInMilitary
# HasStudentDebt
# HomeMortgageOwe
# HoursLearning
# ID.x
# ID.y
# Income
# IsEthnicMinority
# IsReceiveDiabilitiesBenefits
# IsSoftwareDev
# IsUnderEmployed
# JobApplyWhen
# JobPref
# ...

# %%
# Extract only columns 0, 1, 2, 3, 4, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111


dataclean_df = dataunclean_df.iloc[:,[0, 1, 2, 3, 4, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
dataclean_df
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      28.0               0.0             NaN                   NaN
# 1      22.0               0.0             NaN                   NaN
# 2      19.0               0.0             NaN                   NaN
# 3      26.0               0.0             NaN                   NaN
# 4      20.0               0.0             NaN                   NaN
# 5      34.0               0.0             NaN                   NaN
# 6      23.0               0.0             NaN                   NaN
# 7      35.0               0.0             NaN                   NaN
# 8      33.0               0.0             NaN                   NaN
# 9      33.0               0.0             NaN                   NaN
# 10     57.0               0.0             NaN                   NaN
# 11     23.0               0.0             NaN                   NaN
# 12     47.0               0.0             NaN                   NaN
# ...

# %%
# Change "0" to "No" and "1" to "Yes" in response columns
dataclean_df = dataclean_df.replace({0.0 : "No", 1.0 : "Yes"})
dataclean_df.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 0               NaN                 NaN               NaN            NaN
# 1               NaN                 NaN               NaN            NaN
# 2               NaN                 NaN               NaN            NaN
# 3               NaN                 NaN               NaN            NaN
# 4               NaN                 NaN               NaN            NaN
#
#                   CityPopulation CodeEventBootcamp               CountryLive  \
# 0  between 100,000 and 1 million               NaN  United States of America
# ...

# %%
# Calculate total number of respondents in survey
number_respondents=len(dataclean_df)
print(number_respondents)
# Out:
# 15620

# %%
# Extract rows corresponding only to people who attended a bootcamp
Attend_bootcamp = dataclean_df.loc[dataclean_df["AttendedBootcamp"] == "Yes"]
Attend_bootcamp.count()
# Out:
# Age                     818
# AttendedBootcamp        953
# BootcampFinish          933
# BootcampFullJobAfter    635
# BootcampLoanYesNo       934
# BootcampPostSalary      330
# BootcampRecommend       937
# ChildrenNumber          148
# CityPopulation          823
# CodeEventBootcamp        27
# CountryLive             825
# EmploymentField         476
# EmploymentStatus        792
# Gender                  833
# HasChildren             211
# HoursLearning           925
# Income                  430
# JobRoleInterest         402
# SchoolDegree            832
# SchoolMajor             622
# dtype: int64

# %%
# Calculate average age of attendees
mean_age = dataclean_df["Age"].mean()
print(mean_age)

# Calculate how many people attended a bootcamp
Boot_camp_attendees = Attend_bootcamp["AttendedBootcamp"].count()
print(Boot_camp_attendees)

#Calculate how many attendees hold degrees
Attendees_hold_degrees = Attend_bootcamp["SchoolDegree"].count()
print(Attendees_hold_degrees)

# Count number of attendees who self-identify as male; female; or are of non-binary gender identification
Gender_count = Attend_bootcamp['Gender'].count()
Male_count = Attend_bootcamp['Gender'].value_counts()["male"]
Female_count = Attend_bootcamp['Gender'].value_counts()["female"]
NonBinary_count = Gender_count-(Male_count + Female_count)
print(Gender_count)
print(Male_count)
print(Female_count)
print(NonBinary_count)

# Calculate percentage of respondents who attended a bootcamp
Percent_respondents = (Boot_camp_attendees/number_respondents)*100
print(Percent_respondents)

# Calculate percentage of respondents belonging to each gender
Male_Percent = (Male_count/number_respondents) * 100
Female_Percent = (Female_count/number_respondents) * 100
NonBinary_Percent = (NonBinary_count/number_respondents) * 100

# Calculate percentage of attendees with a school degree
School_degree_percent = (Attendees_hold_degrees/Boot_camp_attendees)*100

# Calculate average post-bootcamp salary
Avg_salary = Attend_bootcamp["BootcampPostSalary"].mean()
print(Avg_salary)
# Out:
# 29.17542055388232
# 953
# 832
# 833
# 496
# 326
# 11
# 6.101152368758003
# 63740.50606060606

# %%
# Create a new table consolidating above calculations
new_df = pd.DataFrame([
    {"Average Salary": Avg_salary}, {"Percentage of School degree": School_degree_percent}, {"Male percent of respondents": Male_Percent}, {"Female percent of respondents": Female_Percent}, 
       {"NonBinary percent of respondents": NonBinary_Percent}, {"Number of people attending Bootcamp": Boot_camp_attendees}, 
    {"The number of attendees that hold degrees": Attendees_hold_degrees}, {"Average Age of Attendees": mean_age}])

# Improve formatting before outputting spreadsheet

pd.options.display.float_format = '${:,.2f}'.format

# %%
# Export to Excel
new_df.to_excel("output/DataCleanUp.xls", sheet_name='Sheet_name_1',index=False, header=True)
